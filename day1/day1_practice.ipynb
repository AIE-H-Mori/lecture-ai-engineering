# %% [markdown]
# # 実践演習 Day 1：streamlitとFastAPIのデモ
# このノートブックでは以下の内容を学習します。
#
# - 必要なライブラリのインストールと環境設定
# - Hugging Faceからモデルを用いたStreamlitのデモアプリ
# - FastAPIとngrokを使用したAPIの公開方法
#
# 演習を始める前に、HuggingFaceとngrokのアカウントを作成し、
# それぞれのAPIトークンを取得する必要があります。
#
#
# 演習の時間では、以下の3つのディレクトリを順に説明します。
#
# 1. 01_streamlit_UI
# 2. 02_streamlit_app
# 3. 03_FastAPI
#
# 2つ目や3つ目からでも始められる様にノートブックを作成しています。
#
# 復習の際にもこのノートブックを役立てていただければと思います。
#
# ### 注意事項
# 「02_streamlit_app」と「03_FastAPI」では、GPUを使用します。
#
# これらを実行する際は、Google Colab画面上のメニューから「編集」→ 「ノートブックの設定」
#
# 「ハードウェアアクセラレーター」の項目の中から、「T4 GPU」を選択してください。
#
# このノートブックのデフォルトは「CPU」になっています。
#
# ---

# %% [markdown]
# # 環境変数の設定（1~3共有）

# %% [markdown]
# ### ドライブをマウント

# %%
from google.colab import drive
drive.mount('/content/drive')

# 親フォルダ設定
parent_dir = "/content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# GitHubから演習用のコードをCloneします。

# %%
# !git clone https://github.com/matsuolab/lecture-ai-engineering.git

# %% [markdown]
# 必要なAPIトークンを.envに設定します。
#
# 「lecture-ai-engineering/day1」の配下に、「.env_template」ファイルが存在しています。
#
# 隠しファイルのため表示されていない場合は、画面左側のある、目のアイコンの「隠しファイルの表示」ボタンを押してください。
#
# 「.env_template」のファイル名を「.env」に変更します。「.env」ファイルを開くと、以下のような中身になっています。
#
#
# ```
# HUGGINGFACE_TOKEN="hf-********"
# NGROK_TOKEN="********"
# ```
# ダブルクオーテーションで囲まれた文字列をHuggingfaceのアクセストークンと、ngrokの認証トークンで書き変えてください。
#
# それぞれのアカウントが作成済みであれば、以下のURLからそれぞれのトークンを取得できます。
#
# - Huggingfaceのアクセストークン
# https://huggingface.co/docs/hub/security-tokens
#
# - ngrokの認証トークン
# https://dashboard.ngrok.com/get-started/your-authtoken
#
# 書き換えたら、「.env」ファイルをローカルのPCにダウンロードしてください。
#
# 「01_streamlit_UI」から「02_streamlit_app」へ進む際に、CPUからGPUの利用に切り替えるため、セッションが一度切れてしまいます。
#
# その際に、トークンを設定した「.env」ファイルは再作成することになるので、その手間を減らすために「.env」ファイルをダウンロードしておくと良いです。

# %% [markdown]
# 「.env」ファイルを読み込み、環境変数として設定します。次のセルを実行し、最終的に「True」が表示されていればうまく読み込めています。

# %%
# !pip install python-dotenv
from dotenv import load_dotenv, find_dotenv

# %cd /content/lecture-ai-engineering/day1
# %cd {parent_dir}
# %cd /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1

load_dotenv(find_dotenv())
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.1.0)
# /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1
# True

# %% [markdown]
# # 01_streamlit_UI
#
# ディレクトリ「01_streamlit_UI」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/01_streamlit_UI
practice_dir_01 = parent_dir + "/01_streamlit_UI"
# %cd {practice_dir}
# %cd /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1/01_streamlit_UI
# Out:
# /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1/01_streamlit_UI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# アプリを起動します。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py
# Out:
# 公開URL: https://7ff6-35-226-152-112.ngrok-free.app
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.226.152.112:8501
#
#   Stopping...
#   Stopping...

# %% [markdown]
# 公開URLの後に記載されているURLにブラウザでアクセスすると、streamlitのUIが表示されます。
#
# app.pyのコメントアウトされている箇所を編集することで、UIがどの様に変化するか確認してみましょう。
#
# streamlitの公式ページには、ギャラリーページがあります。
#
# streamlitを使うとpythonという一つの言語であっても、様々なUIを実現できることがわかると思います。
#
# https://streamlit.io/gallery

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 02_streamlit_app

# %% [markdown]
# ディレクトリ「02_streamlit_app」に移動します。

# %%
practice_dir_02 = parent_dir + "/02_streamlit_app"
# %cd {practice_dir_02}
# %cd /content/lecture-ai-engineering/day1/02_streamlit_app
# Out:
# /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1/02_streamlit_app

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `forAIE` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `forAIE`

# %% [markdown]
# stramlitでHuggingfaceのトークン情報を扱うために、streamlit用の設定ファイル（.streamlit）を作成し、トークンの情報を格納します。

# %%
# .streamlit/secrets.toml ファイルを作成
import os
import toml

# 設定ファイルのディレクトリ確保
os.makedirs('.streamlit', exist_ok=True)

# 環境変数から取得したトークンを設定ファイルに書き込む
secrets = {
    "huggingface": {
        "token": os.environ.get("HUGGINGFACE_TOKEN", "")
    }
}

# 設定ファイルを書き込む
with open('.streamlit/secrets.toml', 'w') as f:
    toml.dump(secrets, f)

# %% [markdown]
# アプリを起動します。
#
# 02_streamlit_appでは、Huggingfaceからモデルをダウンロードするため、初回起動には2分程度時間がかかります。
#
# この待ち時間を利用して、app.pyのコードを確認してみましょう。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py
# Out:
# 公開URL: https://bc85-35-226-152-112.ngrok-free.app
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.226.152.112:8501
#
# NLTK loaded successfully.
# 2025-04-20 02:23:43.671809: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745115823.953843    4973 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745115824.029841    4973 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-20 02:23:44.625326: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# config.json: 100% 805/805 [00:00<00:00, 4.00MB/s]
# model.safetensors.index.json: 100% 24.2k/24.2k [00:00<00:00, 7.56MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.99G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/241M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/4.99G [00:00<01:48, 45.8MB/s]
#
# model-00002-of-00002.safetensors:   4% 10.5M/241M [00:00<00:05, 43.7MB/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.99G [00:00<00:54, 91.2MB/s]
#
# model-00002-of-00002.safetensors:   9% 21.0M/241M [00:00<00:03, 56.5MB/s]
#
# model-00002-of-00002.safetensors:  13% 31.5M/241M [00:00<00:02, 71.1MB/s]
# model-00001-of-00002.safetensors:   1% 52.4M/4.99G [00:00<00:44, 111MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/4.99G [00:00<00:40, 121MB/s]
#
# model-00002-of-00002.safetensors:  22% 52.4M/241M [00:00<00:02, 93.3MB/s]
# model-00001-of-00002.safetensors:   2% 94.4M/4.99G [00:00<00:39, 123MB/s]
#
# model-00002-of-00002.safetensors:  30% 73.4M/241M [00:00<00:01, 107MB/s]
#
# model-00002-of-00002.safetensors:  39% 94.4M/241M [00:00<00:01, 124MB/s]
# model-00001-of-00002.safetensors:   2% 115M/4.99G [00:00<00:36, 132MB/s]
#
# model-00002-of-00002.safetensors:  48% 115M/241M [00:01<00:00, 144MB/s]
# model-00001-of-00002.safetensors:   3% 136M/4.99G [00:01<00:36, 134MB/s]
#
# model-00002-of-00002.safetensors:  57% 136M/241M [00:01<00:00, 149MB/s]
# model-00001-of-00002.safetensors:   3% 157M/4.99G [00:01<00:37, 129MB/s]
#
# model-00002-of-00002.safetensors:  65% 157M/241M [00:01<00:00, 138MB/s]
# model-00001-of-00002.safetensors:   4% 178M/4.99G [00:01<00:37, 128MB/s]
#
# model-00002-of-00002.safetensors:  74% 178M/241M [00:01<00:00, 142MB/s]
# model-00001-of-00002.safetensors:   4% 199M/4.99G [00:01<00:37, 126MB/s]
#
# model-00002-of-00002.safetensors:  83% 199M/241M [00:01<00:00, 132MB/s]
# model-00001-of-00002.safetensors:   4% 220M/4.99G [00:01<00:37, 127MB/s]
#
# model-00002-of-00002.safetensors:  91% 220M/241M [00:01<00:00, 138MB/s]
# model-00001-of-00002.safetensors:   5% 241M/4.99G [00:02<00:38, 123MB/s]
#
# model-00002-of-00002.safetensors: 100% 241M/241M [00:02<00:00, 116MB/s]
#
# model-00001-of-00002.safetensors:   5% 262M/4.99G [00:02<00:38, 122MB/s]
# model-00001-of-00002.safetensors:   6% 294M/4.99G [00:02<00:31, 147MB/s]
# model-00001-of-00002.safetensors:   6% 315M/4.99G [00:02<00:31, 151MB/s]
# model-00001-of-00002.safetensors:   7% 346M/4.99G [00:02<00:28, 161MB/s]
# model-00001-of-00002.safetensors:   7% 367M/4.99G [00:02<00:28, 164MB/s]
# model-00001-of-00002.safetensors:   8% 388M/4.99G [00:02<00:26, 173MB/s]
# model-00001-of-00002.safetensors:   8% 409M/4.99G [00:02<00:25, 177MB/s]
# model-00001-of-00002.safetensors:   9% 430M/4.99G [00:03<00:32, 140MB/s]
# model-00001-of-00002.safetensors:   9% 451M/4.99G [00:03<00:31, 145MB/s]
# model-00001-of-00002.safetensors:   9% 472M/4.99G [00:03<00:30, 150MB/s]
# model-00001-of-00002.safetensors:  10% 493M/4.99G [00:03<00:28, 160MB/s]
# model-00001-of-00002.safetensors:  10% 514M/4.99G [00:03<00:26, 170MB/s]
# model-00001-of-00002.safetensors:  11% 535M/4.99G [00:03<00:24, 179MB/s]
# model-00001-of-00002.safetensors:  11% 556M/4.99G [00:03<00:24, 185MB/s]
# model-00001-of-00002.safetensors:  12% 577M/4.99G [00:03<00:23, 191MB/s]
# model-00001-of-00002.safetensors:  12% 598M/4.99G [00:04<00:22, 194MB/s]
# model-00001-of-00002.safetensors:  13% 629M/4.99G [00:04<00:21, 199MB/s]
# model-00001-of-00002.safetensors:  13% 650M/4.99G [00:04<00:21, 202MB/s]
# model-00001-of-00002.safetensors:  13% 671M/4.99G [00:04<00:27, 157MB/s]
# model-00001-of-00002.safetensors:  14% 692M/4.99G [00:04<00:40, 105MB/s]
# model-00001-of-00002.safetensors:  14% 713M/4.99G [00:05<00:37, 115MB/s]
# model-00001-of-00002.safetensors:  15% 734M/4.99G [00:05<00:34, 125MB/s]
# model-00001-of-00002.safetensors:  15% 755M/4.99G [00:05<00:30, 140MB/s]
# model-00001-of-00002.safetensors:  16% 776M/4.99G [00:05<00:27, 153MB/s]
# model-00001-of-00002.safetensors:  16% 807M/4.99G [00:05<00:24, 171MB/s]
# model-00001-of-00002.safetensors:  17% 828M/4.99G [00:05<00:23, 175MB/s]
# model-00001-of-00002.safetensors:  17% 849M/4.99G [00:05<00:22, 181MB/s]
# model-00001-of-00002.safetensors:  17% 870M/4.99G [00:05<00:26, 155MB/s]
# model-00001-of-00002.safetensors:  18% 891M/4.99G [00:06<00:25, 159MB/s]
# model-00001-of-00002.safetensors:  18% 912M/4.99G [00:06<00:26, 153MB/s]
# model-00001-of-00002.safetensors:  19% 933M/4.99G [00:06<00:24, 164MB/s]
# model-00001-of-00002.safetensors:  19% 965M/4.99G [00:06<00:21, 183MB/s]
# model-00001-of-00002.safetensors:  20% 996M/4.99G [00:06<00:20, 192MB/s]
# model-00001-of-00002.safetensors:  20% 1.02G/4.99G [00:06<00:21, 186MB/s]
# model-00001-of-00002.safetensors:  21% 1.04G/4.99G [00:06<00:26, 149MB/s]
# model-00001-of-00002.safetensors:  21% 1.06G/4.99G [00:07<00:25, 154MB/s]
# model-00001-of-00002.safetensors:  22% 1.08G/4.99G [00:07<00:33, 115MB/s]
# model-00001-of-00002.safetensors:  22% 1.10G/4.99G [00:07<00:31, 123MB/s]
# model-00001-of-00002.safetensors:  22% 1.12G/4.99G [00:07<00:30, 129MB/s]
# model-00001-of-00002.safetensors:  23% 1.14G/4.99G [00:07<00:28, 136MB/s]
# model-00001-of-00002.safetensors:  23% 1.16G/4.99G [00:07<00:25, 149MB/s]
# model-00001-of-00002.safetensors:  24% 1.18G/4.99G [00:08<00:25, 148MB/s]
# model-00001-of-00002.safetensors:  24% 1.21G/4.99G [00:08<00:28, 135MB/s]
# model-00001-of-00002.safetensors:  25% 1.23G/4.99G [00:08<00:49, 76.4MB/s]
# model-00001-of-00002.safetensors:  25% 1.25G/4.99G [00:09<00:46, 79.8MB/s]
# model-00001-of-00002.safetensors:  25% 1.27G/4.99G [00:09<00:39, 94.3MB/s]
# model-00001-of-00002.safetensors:  26% 1.29G/4.99G [00:09<00:33, 111MB/s]
# model-00001-of-00002.safetensors:  26% 1.32G/4.99G [00:09<00:26, 137MB/s]
# model-00001-of-00002.safetensors:  27% 1.34G/4.99G [00:09<00:24, 148MB/s]
# model-00001-of-00002.safetensors:  28% 1.37G/4.99G [00:09<00:21, 169MB/s]
# model-00001-of-00002.safetensors:  28% 1.41G/4.99G [00:09<00:19, 181MB/s]
# model-00001-of-00002.safetensors:  29% 1.43G/4.99G [00:09<00:19, 180MB/s]
# model-00001-of-00002.safetensors:  29% 1.45G/4.99G [00:10<00:25, 139MB/s]
# model-00001-of-00002.safetensors:  29% 1.47G/4.99G [00:10<00:39, 90.0MB/s]
# model-00001-of-00002.safetensors:  30% 1.49G/4.99G [00:10<00:44, 78.2MB/s]
# model-00001-of-00002.safetensors:  30% 1.52G/4.99G [00:11<00:40, 86.5MB/s]
# model-00001-of-00002.safetensors:  31% 1.54G/4.99G [00:11<00:33, 102MB/s]
# model-00001-of-00002.safetensors:  31% 1.56G/4.99G [00:11<00:30, 111MB/s]
# model-00001-of-00002.safetensors:  32% 1.58G/4.99G [00:11<00:28, 120MB/s]
# model-00001-of-00002.safetensors:  32% 1.60G/4.99G [00:11<00:28, 118MB/s]
# model-00001-of-00002.safetensors:  33% 1.63G/4.99G [00:11<00:25, 129MB/s]
# model-00001-of-00002.safetensors:  33% 1.65G/4.99G [00:12<00:36, 92.7MB/s]
# model-00001-of-00002.safetensors:  33% 1.67G/4.99G [00:12<00:40, 82.2MB/s]
# model-00001-of-00002.safetensors:  34% 1.69G/4.99G [00:12<00:34, 96.9MB/s]
# model-00001-of-00002.safetensors:  34% 1.71G/4.99G [00:13<00:34, 95.5MB/s]
# model-00001-of-00002.safetensors:  35% 1.73G/4.99G [00:13<00:39, 83.4MB/s]
# model-00001-of-00002.safetensors:  35% 1.75G/4.99G [00:13<00:38, 85.1MB/s]
# model-00001-of-00002.safetensors:  36% 1.77G/4.99G [00:13<00:38, 83.4MB/s]
# model-00001-of-00002.safetensors:  36% 1.78G/4.99G [00:14<00:42, 75.5MB/s]
# model-00001-of-00002.safetensors:  36% 1.80G/4.99G [00:14<00:38, 82.0MB/s]
# model-00001-of-00002.safetensors:  36% 1.81G/4.99G [00:14<00:38, 82.9MB/s]
# model-00001-of-00002.safetensors:  37% 1.82G/4.99G [00:14<00:41, 76.5MB/s]
# model-00001-of-00002.safetensors:  37% 1.85G/4.99G [00:14<00:41, 75.3MB/s]
# model-00001-of-00002.safetensors:  37% 1.86G/4.99G [00:15<00:48, 65.2MB/s]
# model-00001-of-00002.safetensors:  38% 1.88G/4.99G [00:15<00:35, 86.4MB/s]
# model-00001-of-00002.safetensors:  38% 1.89G/4.99G [00:15<00:35, 87.7MB/s]
# model-00001-of-00002.safetensors:  38% 1.91G/4.99G [00:15<00:27, 110MB/s]
# model-00001-of-00002.safetensors:  39% 1.94G/4.99G [00:15<00:21, 142MB/s]
# model-00001-of-00002.safetensors:  39% 1.96G/4.99G [00:15<00:20, 149MB/s]
# model-00001-of-00002.safetensors:  40% 1.99G/4.99G [00:15<00:17, 172MB/s]
# model-00001-of-00002.safetensors:  40% 2.01G/4.99G [00:15<00:17, 168MB/s]
# model-00001-of-00002.safetensors:  41% 2.03G/4.99G [00:16<00:17, 167MB/s]
# model-00001-of-00002.safetensors:  41% 2.06G/4.99G [00:16<00:17, 165MB/s]
# model-00001-of-00002.safetensors:  42% 2.08G/4.99G [00:16<00:17, 170MB/s]
# model-00001-of-00002.safetensors:  42% 2.10G/4.99G [00:16<00:17, 163MB/s]
# model-00001-of-00002.safetensors:  42% 2.12G/4.99G [00:16<00:17, 164MB/s]
# model-00001-of-00002.safetensors:  43% 2.14G/4.99G [00:16<00:17, 166MB/s]
# model-00001-of-00002.safetensors:  44% 2.17G/4.99G [00:16<00:15, 180MB/s]
# model-00001-of-00002.safetensors:  44% 2.19G/4.99G [00:17<00:15, 175MB/s]
# model-00001-of-00002.safetensors:  44% 2.21G/4.99G [00:20<02:18, 20.0MB/s]
# model-00001-of-00002.safetensors:  45% 2.23G/4.99G [00:20<01:42, 26.9MB/s]
# model-00001-of-00002.safetensors:  45% 2.26G/4.99G [00:20<01:07, 40.5MB/s]
# model-00001-of-00002.safetensors:  46% 2.29G/4.99G [00:20<00:53, 50.7MB/s]
# model-00001-of-00002.safetensors:  46% 2.32G/4.99G [00:20<00:37, 70.5MB/s]
# model-00001-of-00002.safetensors:  47% 2.34G/4.99G [00:21<00:31, 84.4MB/s]
# model-00001-of-00002.safetensors:  47% 2.36G/4.99G [00:21<00:26, 99.3MB/s]
# model-00001-of-00002.safetensors:  48% 2.38G/4.99G [00:21<00:22, 115MB/s]
# model-00001-of-00002.safetensors:  48% 2.40G/4.99G [00:21<00:19, 131MB/s]
# model-00001-of-00002.safetensors:  49% 2.42G/4.99G [00:21<00:19, 130MB/s]
# model-00001-of-00002.safetensors:  49% 2.45G/4.99G [00:21<00:16, 158MB/s]
# model-00001-of-00002.safetensors:  50% 2.47G/4.99G [00:21<00:15, 165MB/s]
# model-00001-of-00002.safetensors:  50% 2.50G/4.99G [00:21<00:15, 165MB/s]
# model-00001-of-00002.safetensors:  50% 2.52G/4.99G [00:22<00:14, 171MB/s]
# model-00001-of-00002.safetensors:  51% 2.54G/4.99G [00:22<00:14, 174MB/s]
# model-00001-of-00002.safetensors:  51% 2.56G/4.99G [00:22<00:13, 181MB/s]
# model-00001-of-00002.safetensors:  52% 2.58G/4.99G [00:22<00:12, 186MB/s]
# model-00001-of-00002.safetensors:  52% 2.61G/4.99G [00:22<00:12, 196MB/s]
# model-00001-of-00002.safetensors:  53% 2.64G/4.99G [00:23<00:38, 60.3MB/s]
# model-00001-of-00002.safetensors:  54% 2.67G/4.99G [00:23<00:29, 79.4MB/s]
# model-00001-of-00002.safetensors:  54% 2.71G/4.99G [00:23<00:22, 99.9MB/s]
# model-00001-of-00002.safetensors:  55% 2.73G/4.99G [00:24<00:19, 114MB/s]
# model-00001-of-00002.safetensors:  55% 2.75G/4.99G [00:24<00:17, 128MB/s]
# model-00001-of-00002.safetensors:  55% 2.77G/4.99G [00:24<00:17, 129MB/s]
# model-00001-of-00002.safetensors:  56% 2.79G/4.99G [00:24<00:15, 144MB/s]
# model-00001-of-00002.safetensors:  57% 2.82G/4.99G [00:24<00:13, 163MB/s]
# model-00001-of-00002.safetensors:  57% 2.85G/4.99G [00:24<00:12, 172MB/s]
# model-00001-of-00002.safetensors:  58% 2.87G/4.99G [00:24<00:12, 168MB/s]
# model-00001-of-00002.safetensors:  58% 2.90G/4.99G [00:25<00:11, 181MB/s]
# model-00001-of-00002.safetensors:  59% 2.93G/4.99G [00:25<00:16, 125MB/s]
# model-00001-of-00002.safetensors:  59% 2.95G/4.99G [00:25<00:21, 94.2MB/s]
# model-00001-of-00002.safetensors:  59% 2.97G/4.99G [00:26<00:27, 72.9MB/s]
# model-00001-of-00002.safetensors:  60% 2.98G/4.99G [00:26<00:29, 68.3MB/s]
# model-00001-of-00002.safetensors:  60% 2.99G/4.99G [00:26<00:28, 70.7MB/s]
# model-00001-of-00002.safetensors:  60% 3.00G/4.99G [00:26<00:27, 72.3MB/s]
# model-00001-of-00002.safetensors:  60% 3.01G/4.99G [00:26<00:27, 72.9MB/s]
# model-00001-of-00002.safetensors:  61% 3.02G/4.99G [00:26<00:26, 74.2MB/s]
# model-00001-of-00002.safetensors:  61% 3.04G/4.99G [00:27<00:21, 88.7MB/s]
# model-00001-of-00002.safetensors:  61% 3.06G/4.99G [00:27<00:23, 82.0MB/s]
# model-00001-of-00002.safetensors:  62% 3.07G/4.99G [00:27<00:27, 70.1MB/s]
# model-00001-of-00002.safetensors:  62% 3.09G/4.99G [00:27<00:28, 66.7MB/s]
# model-00001-of-00002.safetensors:  62% 3.10G/4.99G [00:28<00:27, 67.5MB/s]
# model-00001-of-00002.safetensors:  62% 3.11G/4.99G [00:28<00:30, 61.9MB/s]
# model-00001-of-00002.safetensors:  63% 3.14G/4.99G [00:28<00:23, 80.3MB/s]
# model-00001-of-00002.safetensors:  63% 3.17G/4.99G [00:28<00:15, 115MB/s]
# model-00001-of-00002.safetensors:  64% 3.20G/4.99G [00:28<00:12, 146MB/s]
# model-00001-of-00002.safetensors:  65% 3.23G/4.99G [00:28<00:10, 160MB/s]
# model-00001-of-00002.safetensors:  65% 3.25G/4.99G [00:29<00:10, 163MB/s]
# model-00001-of-00002.safetensors:  66% 3.27G/4.99G [00:29<00:10, 168MB/s]
# model-00001-of-00002.safetensors:  66% 3.29G/4.99G [00:29<00:09, 175MB/s]
# model-00001-of-00002.safetensors:  66% 3.31G/4.99G [00:29<00:09, 174MB/s]
# model-00001-of-00002.safetensors:  67% 3.33G/4.99G [00:29<00:09, 179MB/s]
# model-00001-of-00002.safetensors:  67% 3.36G/4.99G [00:29<00:09, 178MB/s]
# model-00001-of-00002.safetensors:  68% 3.39G/4.99G [00:29<00:08, 191MB/s]
# model-00001-of-00002.safetensors:  69% 3.42G/4.99G [00:29<00:07, 201MB/s]
# model-00001-of-00002.safetensors:  69% 3.44G/4.99G [00:29<00:07, 199MB/s]
# model-00001-of-00002.safetensors:  69% 3.46G/4.99G [00:30<00:07, 199MB/s]
# model-00001-of-00002.safetensors:  70% 3.48G/4.99G [00:30<00:07, 195MB/s]
# model-00001-of-00002.safetensors:  70% 3.50G/4.99G [00:30<00:07, 198MB/s]
# model-00001-of-00002.safetensors:  71% 3.52G/4.99G [00:30<00:07, 197MB/s]
# model-00001-of-00002.safetensors:  71% 3.54G/4.99G [00:34<01:31, 15.7MB/s]
# model-00001-of-00002.safetensors:  71% 3.57G/4.99G [00:34<01:06, 21.5MB/s]
# model-00001-of-00002.safetensors:  72% 3.59G/4.99G [00:35<00:49, 28.2MB/s]
# model-00001-of-00002.safetensors:  72% 3.61G/4.99G [00:35<00:36, 37.6MB/s]
# model-00001-of-00002.safetensors:  73% 3.64G/4.99G [00:35<00:24, 55.9MB/s]
# model-00001-of-00002.safetensors:  74% 3.67G/4.99G [00:35<00:17, 74.7MB/s]
# model-00001-of-00002.safetensors:  74% 3.69G/4.99G [00:35<00:16, 77.8MB/s]
# model-00001-of-00002.safetensors:  74% 3.71G/4.99G [00:35<00:14, 88.1MB/s]
# model-00001-of-00002.safetensors:  75% 3.73G/4.99G [00:35<00:12, 100MB/s]
# model-00001-of-00002.safetensors:  75% 3.75G/4.99G [00:36<00:12, 99.8MB/s]
# model-00001-of-00002.safetensors:  76% 3.77G/4.99G [00:36<00:13, 88.4MB/s]
# model-00001-of-00002.safetensors:  76% 3.80G/4.99G [00:36<00:13, 89.8MB/s]
# model-00001-of-00002.safetensors:  77% 3.82G/4.99G [00:37<00:21, 55.2MB/s]
# model-00001-of-00002.safetensors:  77% 3.84G/4.99G [00:37<00:17, 67.5MB/s]
# model-00001-of-00002.safetensors:  77% 3.86G/4.99G [00:37<00:13, 84.2MB/s]
# model-00001-of-00002.safetensors:  78% 3.88G/4.99G [00:37<00:11, 100MB/s]
# model-00001-of-00002.safetensors:  78% 3.91G/4.99G [00:38<00:10, 102MB/s]
# model-00001-of-00002.safetensors:  79% 3.93G/4.99G [00:38<00:10, 98.8MB/s]
# model-00001-of-00002.safetensors:  79% 3.95G/4.99G [00:40<00:31, 32.6MB/s]
# model-00001-of-00002.safetensors:  80% 3.97G/4.99G [00:40<00:24, 40.6MB/s]
# model-00001-of-00002.safetensors:  80% 3.98G/4.99G [00:41<00:38, 26.4MB/s]
# model-00001-of-00002.safetensors:  80% 4.01G/4.99G [00:41<00:27, 36.0MB/s]
# model-00001-of-00002.safetensors:  81% 4.04G/4.99G [00:41<00:17, 55.1MB/s]
# model-00001-of-00002.safetensors:  82% 4.07G/4.99G [00:41<00:12, 76.2MB/s]
# model-00001-of-00002.safetensors:  82% 4.09G/4.99G [00:41<00:10, 89.1MB/s]
# model-00001-of-00002.safetensors:  82% 4.11G/4.99G [00:42<00:08, 105MB/s]
# model-00001-of-00002.safetensors:  83% 4.14G/4.99G [00:42<00:06, 129MB/s]
# model-00001-of-00002.safetensors:  83% 4.16G/4.99G [00:42<00:05, 143MB/s]
# model-00001-of-00002.safetensors:  84% 4.19G/4.99G [00:42<00:04, 162MB/s]
# model-00001-of-00002.safetensors:  85% 4.23G/4.99G [00:42<00:04, 180MB/s]
# model-00001-of-00002.safetensors:  85% 4.26G/4.99G [00:42<00:03, 194MB/s]
# model-00001-of-00002.safetensors:  86% 4.29G/4.99G [00:42<00:03, 201MB/s]
# model-00001-of-00002.safetensors:  87% 4.32G/4.99G [00:42<00:03, 210MB/s]
# model-00001-of-00002.safetensors:  87% 4.35G/4.99G [00:43<00:02, 213MB/s]
# model-00001-of-00002.safetensors:  88% 4.38G/4.99G [00:43<00:02, 221MB/s]
# model-00001-of-00002.safetensors:  89% 4.41G/4.99G [00:43<00:02, 211MB/s]
# model-00001-of-00002.safetensors:  89% 4.45G/4.99G [00:43<00:02, 204MB/s]
# model-00001-of-00002.safetensors:  90% 4.47G/4.99G [00:43<00:02, 201MB/s]
# model-00001-of-00002.safetensors:  90% 4.50G/4.99G [00:43<00:02, 207MB/s]
# model-00001-of-00002.safetensors:  91% 4.52G/4.99G [00:47<00:18, 25.3MB/s]
# model-00001-of-00002.safetensors:  91% 4.55G/4.99G [00:47<00:12, 36.4MB/s]
# model-00001-of-00002.safetensors:  92% 4.58G/4.99G [00:47<00:08, 49.1MB/s]
# model-00001-of-00002.safetensors:  92% 4.60G/4.99G [00:47<00:06, 59.1MB/s]
# model-00001-of-00002.safetensors:  93% 4.62G/4.99G [00:47<00:05, 67.9MB/s]
# model-00001-of-00002.safetensors:  93% 4.65G/4.99G [00:47<00:04, 80.6MB/s]
# model-00001-of-00002.safetensors:  94% 4.67G/4.99G [00:47<00:03, 94.6MB/s]
# model-00001-of-00002.safetensors:  94% 4.69G/4.99G [00:47<00:02, 111MB/s]
# model-00001-of-00002.safetensors:  94% 4.71G/4.99G [00:48<00:02, 127MB/s]
# model-00001-of-00002.safetensors:  95% 4.74G/4.99G [00:48<00:01, 154MB/s]
# model-00001-of-00002.safetensors:  96% 4.77G/4.99G [00:48<00:01, 175MB/s]
# model-00001-of-00002.safetensors:  96% 4.80G/4.99G [00:48<00:01, 185MB/s]
# model-00001-of-00002.safetensors:  97% 4.83G/4.99G [00:48<00:00, 196MB/s]
# model-00001-of-00002.safetensors:  98% 4.87G/4.99G [00:48<00:00, 207MB/s]
# model-00001-of-00002.safetensors:  98% 4.90G/4.99G [00:48<00:00, 208MB/s]
# model-00001-of-00002.safetensors:  99% 4.93G/4.99G [00:49<00:00, 219MB/s]
# model-00001-of-00002.safetensors:  99% 4.96G/4.99G [00:49<00:00, 222MB/s]
# model-00001-of-00002.safetensors: 100% 4.99G/4.99G [00:49<00:00, 101MB/s]
# Fetching 2 files: 100% 2/2 [00:49<00:00, 24.76s/it]
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  9.75it/s]
# generation_config.json: 100% 168/168 [00:00<00:00, 1.12MB/s]
# tokenizer_config.json: 100% 46.9k/46.9k [00:00<00:00, 2.37MB/s]
# tokenizer.model: 100% 4.24M/4.24M [00:00<00:00, 48.8MB/s]
# tokenizer.json: 100% 17.5M/17.5M [00:00<00:00, 105MB/s]
# special_tokens_map.json: 100% 555/555 [00:00<00:00, 3.84MB/s]
# Device set to use cpu
# 2025-04-20 02:24:49.270 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/_classes.py", line 13, in __getattr__
#     proxy = torch._C._get_custom_class_python_wrapper(self.name, attr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Generated response in 29.48s
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Generated response in 117.24s
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# 2025-04-20 02:35:43.564 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/_classes.py", line 13, in __getattr__
#     proxy = torch._C._get_custom_class_python_wrapper(self.name, attr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Generated response in 768.26s
# Generated response in 769.73s
# Generated response in 717.62s
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Data saved to DB successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# WARNING:pyngrok.process.ngrok:t=2025-04-20T02:57:16+0000 lvl=warn msg="Stopping forwarder" name=http-8501-a44f7cbf-dd40-4b87-bece-b606b3343809 acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2025-04-20T02:57:16+0000 lvl=warn msg="Error restarting forwarder" name=http-8501-a44f7cbf-dd40-4b87-bece-b606b3343809 err="failed to start tunnel: session closed"
#   Stopping...
#   Stopping...

# %% [markdown]
# アプリケーションの機能としては、チャット機能や履歴閲覧があります。
#
# これらの機能を実現するためには、StreamlitによるUI部分だけではなく、SQLiteを使用したチャット履歴の保存やLLMのモデルを呼び出した推論などの処理を組み合わせることで実現しています。
#
# - **`app.py`**: アプリケーションのエントリーポイント。チャット機能、履歴閲覧、サンプルデータ管理のUIを提供します。
# - **`ui.py`**: チャットページや履歴閲覧ページなど、アプリケーションのUIロジックを管理します。
# - **`llm.py`**: LLMモデルのロードとテキスト生成を行うモジュール。
# - **`database.py`**: SQLiteデータベースを使用してチャット履歴やフィードバックを保存・管理します。
# - **`metrics.py`**: BLEUスコアやコサイン類似度など、回答の評価指標を計算するモジュール。
# - **`data.py`**: サンプルデータの作成やデータベースの初期化を行うモジュール。
# - **`config.py`**: アプリケーションの設定（モデル名やデータベースファイル名）を管理します。
# - **`requirements.txt`**: このアプリケーションを実行するために必要なPythonパッケージ。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 03_FastAPI
#
# ディレクトリ「03_FastAPI」に移動します。

# %%
practice_dir_03 = parent_dir + "/03_FastAPI"
# %cd {practice_dir_03}
# %cd /content/lecture-ai-engineering/day1/03_FastAPI
# Out:
# /content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1/03_FastAPI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `forAIE` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `forAIE`

# %% [markdown]
# アプリを起動します。
#
# 「02_streamlit_app」から続けて「03_FastAPI」を実行している場合は、モデルのダウンロードが済んでいるため、すぐにサービスが立ち上がります。
#
# 「03_FastAPI」のみを実行している場合は、初回の起動時にモデルのダウンロードが始まるので、モデルのダウンロードが終わるまで数分間待ちましょう。

# %%
# !python app.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/AIエンジニアリング講座/gitclone/lecture-ai-engineering/day1/03_FastAPI/app.py", line 2, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 405, in <module>
#     from torch._C import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
# ^C

# %% [markdown]
# FastAPIが起動すると、APIとクライアントが通信するためのURL（エンドポイント）が作られます。
#
# URLが作られるのと合わせて、Swagger UIというWebインターフェースが作られます。
#
# Swagger UIにアクセスすることで、APIの仕様を確認できたり、APIをテストすることができます。
#
# Swagger UIを利用することで、APIを通してLLMを動かしてみましょう。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()
